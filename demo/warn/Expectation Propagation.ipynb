# %% [markdown]
# # Expectation Propagation

# %% [markdown]
# ReactiveMP comes with support for expectation propagation (EP). In this demo we illustrate EP in the context of state-estimation in a linear state-space model that combines a Gaussian state-evolution model with a discrete observation model. Here, the probit function links continuous variable $x_t$ with the discrete variable $y_t$. The model is defined as:

# %% [markdown]
# \begin{align}
#     u &= 0.1 \\
#     x_0 &\sim \mathcal{N}(0, 100) \\
#     x_t &\sim \mathcal{N}(x_{t-1}+ u, 0.01) \\
#     y_t &\sim \mathrm{Ber}(\Phi(x_t))
# \end{align}

# %% [markdown]
# ## Import packages

# %%
using StatsFuns: normcdf
using Random
using PyPlot
using Revise

using ReactiveMP
using GraphPPL
using Rocket
# Out:
#   Activating environment at `~/.julia/dev/ReactiveMP/Project.toml`

# %% [markdown]
# ##  Data generation

# %%
function generate_data(nr_samples::Int64)
    
    # hyper parameters
    u = 0.1

    # allocate space for data
    data_x = zeros(nr_samples + 1)
    data_y = zeros(nr_samples)
    
    # initialize data
    data_x[1] = -2
    
    # generate data
    for k = 2:nr_samples + 1
        
        # calculate new x
        data_x[k] = data_x[k-1] + u + sqrt(0.01)*randn()
        
        # calculate y
        data_y[k-1] = normcdf(data_x[k]) > rand()
        
    end
    
    # return data
    return data_x, data_y
    
end;

# %%
n = 40
# Out:
# 40

# %%
data_x, data_y = generate_data(n);

# %%
plt.figure()
plt.scatter(1:n, data_y, label="y")
plt.plot(data_x, label="x")
plt.xlabel("t")
plt.ylabel("x, y")
plt.legend()
plt.grid();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Model specification

# %%
# TODO: check
@model [default_factorisation=FullFactorisation()] function probit_model(nr_samples::Int64)
    
    # allocate space for variables
    x = randomvar(nr_samples + 1)
    y = datavar(Float64, nr_samples)
    
    # specify uninformative prior
    x[1] ~ NormalMeanPrecision(0.0, 0.01)
    
    # create model 
    for k = 2:nr_samples + 1
        x[k] ~ NormalMeanPrecision(x[k - 1] + 0.1, 100)
        y[k - 1] ~ Probit(x[k]) where {
            # Probit node by default uses RequireInbound pipeline with vague(NormalMeanPrecision) message as initial value for `in` edge
            # To change initial value use may specify it manually, like
            # pipeline = RequireInbound(in = NormalMeanPrecision(0, 1.0)) 
        }
    end
    
    # return parameters
    return x, y
    
end;

# %% [markdown]
# ## Inference

# %%
result = inference(model=Model(probit_model, length(data_y)), data=Dict(:y => data_y), iterations=100, showprogress=true);

# %%
mx = result.posteriors[:x][end]
# Out:
# 41-element Vector{Marginal}:
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-9.377503113205568, w=6.084714084888308))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-9.33624258934794, w=6.47760144144741))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-9.229587177399141, w=6.889108060833357))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-9.045401597810915, w=7.317250854635774))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-8.770616642565466, w=7.7592871708186))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-8.391457525516795, w=8.211638052627546))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-7.893764886003108, w=8.66982895087384))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-7.2634156715305505, w=9.128453655548238))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-6.486848106202676, w=9.581166522334506))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-5.551691947934238, w=10.0207071278634))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-4.600699587590599, w=10.3879148718523))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-3.497260806541348, w=10.719869487704528))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=-2.413068159270783, w=10.97635808489309))
#  ⋮
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=11.867613797297238, w=7.307638467710307))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.019672427199307, w=6.948667226641702))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.12180010985125, w=6.6078142910120174))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.182495819701794, w=6.285400092004259))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.209230054650508, w=5.981404147722915))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.208490991848072, w=5.695532172862799))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.185850060576596, w=5.427277211769588))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.14603981048972, w=5.1759737899574025))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.093038142955608, w=4.940844649202678))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=12.030154197037257, w=4.721040090542366))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=11.960112345121363, w=4.515670289714928))
#  Marginal(NormalWeightedMeanPrecision{Float64}(xi=11.885131792577731, w=4.32383117728807))

# %% [markdown]
# ## Results

# %%
plt.figure()
plt.scatter(1:n, data_y, label="y", color="blue")
plt.plot(data_x, label="x (true)", color="blue")
plt.plot(mean.(mx), label="x (inferred mean)", color="orange")
plt.fill_between(0:n, mean.(mx) .- std.(mx), mean.(mx) + std.(mx), label="x (inferred ±σ)", alpha=0.3, color="orange")
plt.xlabel("t")
plt.ylabel("x, y")
plt.legend()
plt.grid();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
